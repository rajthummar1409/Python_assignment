# %%
name = input("Enter your Name :")
roll = int(input("Enter your RollnumBER :"))
room = int(input("Enter Division :"))

eng  = int(input("Enter English Marks :"))
math = int(input("Enter Math Marks :"))
sci  = int(input("Enter Scince Marks :"))
ss   = int(input("Enter Sosial scince Marks :"))
hindi = int(input("Enter Hindi marks :"))


if eng>100:
        print("Enter valid Marks of English")
elif eng>90 and eng<=100:
        enggrd='A+'
        engremarks="Excellent"
elif eng>80 and eng<=90:
        enggrd='A'
        engremarks="Very good"
elif eng>70 and eng<=80:
        enggrd='B'
        engremarks="Good"
elif eng>60 and eng<=70:
        enggrd='c'
        engremarks="Good"
elif eng>50 and eng<=60:
        enggrd='D'
        engremarks="Batter"
elif eng>33 and eng<=50:
        enggrd='E'
        engremarks="Try batter"
else:
    enggrd='F'
    engremarks="Poor"

    

if math>100:
    print("Enter Velid Marks of Maths")
elif math>90 and math<=100:
        mathgrd='A+'
        mathremarks="Excellent"
elif math>80 and math<=90:
        mathgrd='A'
        mathremarks="Very good" 
elif math>70 and math<=80:
        mathgrd='B'
        mathremarks="Good" 
elif math>60 and math<=70:
        mathgrd='c'
        mathremarks="Good" 
elif math>50 and math<=60:
        mathgrd='D'
        mathremarks="Batter" 
elif math>33 and math<=50:
        mathgrd='E'
        mathremarks="Try batter" 
else:
    mathgrd='F'
    mathremarks="Poor" 
    

if sci>100:
    print("Enter valid Marks of Scince")
elif sci>90 and sci<=100:
        scigrd='A+'
        sciremarks="Excellent" 
elif sci>80 and sci<=90:
        scigrd='A'
        sciremarks="Very good" 
elif sci>70 and sci<=80:
        scigrd='B'
        sciremarks="Good"
elif sci>60 and sci<=70:
        scigrd='c'
        sciremarks="Good"
elif sci>50 and sci<=60:
        scigrd='D'
        sciremarks="Batter"
elif sci>33 and sci<=50:
        scigrd='E'
        sciremarks="Try batter"
else:
    scigrd='F'
    sciremarks="Poor"
    


if ss>100:
    print("Enter valide Marks of SS")
elif ss>90 and ss<=100:
        ssgrd='A+'
        ssremarks="Excellent" 
elif ss>80 and ss<=90:
        ssgrd='A'
        ssremarks="Very good"
elif ss>70 and ss<=80:
        ssgrd='B'
        ssremarks="Good"
elif ss>60 and ss<=70:
        ssgrd='c'
        ssremarks="Good"
elif ss>50 and ss<=60:
        ssgrd='D'
        ssremarks="Batter"
elif ss>33 and ss<=50:
        ssgrd='E'
        ssremarks="Try batter"
else:
    ssgrd='F'
    ssremarks="Poor"
    


if hindi>100:
    print("Enter valid Marks of Hindi")   
elif hindi>90 and hindi<=100:
        hidgrd='A+'
        hindremarks="Excellent" 
elif hindi>80 and hindi<=90:
        hidgrd='A'
        hindremarks="Very good"
elif hindi>70 and hindi<=80:
        hidgrd='B'
        hindremarks="Good"
elif hindi>60 and hindi<=70:
        hidgrd='c'
        hindremarks="Good"
elif hindi>50 and hindi<=60:
        hidgrd='D'
        hindremarks="Batter"
elif hindi>33 and hindi<=50:
        hidgrd='E'
        hindremarks="Try batter"
else:
    hidgrd='F'
    hindremarks="Poor"

total = eng+math+sci+ss+hindi
persentage = total/5    

#Rank

if persentage>90 and persentage<=100:
        rank='1'
elif persentage>80 and persentage<=90:
        rank='2'
elif persentage>70 and persentage<=80:
        rank='3'
elif persentage>60 and persentage<=70:
        rank='4'
elif persentage>50 and persentage<=60:
        rank='5'
elif persentage>33 and persentage<=50:
        rank='6'
else:
    rank='0'
    
#Grde
if persentage>90 and persentage<=100:
        gread1='A+'
        gread2='Pass'
elif persentage>80 and persentage<=90:
        gread1='A'
        gread2='Pass'
elif persentage>70 and persentage<=80:
        gread1='B'
        gread2='Pass'
elif persentage>60 and persentage<=70:
        gread1='c'
        gread2='Pass'
elif persentage>50 and persentage<=60:
        gread1='D'
        gread2='Pass'
elif persentage>33 and persentage<=50:
        gread1='E'
        gread2='Pass'
else:
    gread='F'
    gread2='Fail'
    



   



print(f"""\t\t\t\tTerm-1 Report Card\n\t\t\t\tAcademic Year 2022-23\n\n\tRoll No : {roll}\t\tclass : {room} \t\tAttendence : 70%\n\tStubent Name : {name}\t\t\t\tGR no : 2556\n\n\n\tSubject\t\tTotalmarks\tMarksobtain\tSubjectgrade\tRemarks\n\n1\tEnglish\t\t100\t\t{eng}\t\t{enggrd}\t\t{engremarks}\n\n2\tMaths\t\t100\t\t{math}\t\t{mathgrd}\t\t{mathremarks}\n\n3\tScince\t\t100\t\t{sci}\t\t{scigrd}\t\t{sciremarks}\n\n4\tSocialSci\t100\t\t{ss}\t\t{ssgrd}\t\t{ssremarks}\n\n5\tHindi\t\t100\t\t{hindi}\t\t{hidgrd}\t\t{hindremarks}\n\n\tTotal\t\t500\t\t{total}\n\n\tRank : {rank}\tGrade : {gread1}\tOverall Percentage : {persentage} %\n\n\t\t\tYou {gread2} this Exam\n\n\t\t\t\tGrading System\n\n\t\t91-100\t81-90\t71-80\t61-70\t51-60\t34-50\t0-33\n\t\t  A+\t  A\t  B\t  C\t  D\t  E\tFail""")
# Out:
# Enter your Name :arpit
# Enter your RollnumBER :25
# Enter Division :3
# Enter English Marks :65
# Enter Math Marks :85
# Enter Scince Marks :65
# Enter Sosial scince Marks :95
# Enter Hindi marks :45
# 				Term-1 Report Card
# 				Academic Year 2022-23
#
# 	Roll No : 25		class : 3 		Attendence : 70%
# 	Stubent Name : arpit				GR no : 2556
#
#
# 	Subject		Totalmarks	Marksobtain	Subjectgrade	Remarks
#
# 1	English		100		65		c		Good
#
# 2	Maths		100		85		A		Very good
#
# 3	Scince		100		65		c		Good
#
# 4	SocialSci	100		95		A+		Excellent
#
# 5	Hindi		100		45		E		Try batter
#
# 	Total		500		355
#
# 	Rank : 3	Grade : B	Overall Percentage : 71.0 %
#
# 			You Pass this Exam
#
# 				Grading System
#
# 		91-100	81-90	71-80	61-70	51-60	34-50	0-33
# 		  A+	  A	  B	  C	  D	  E	Fail
